# %%
import tensorflow
from tensorflow.keras.applications.resnet50 import ResNet50,preprocess_input,decode_predictions
from tensorflow.keras.layers import GlobalMaxPooling2D

# %%
model=ResNet50(weights='imagenet',include_top=False,input_shape=(224,224,3))
model.trainable=False

# %%
model=tensorflow.keras.Sequential([
    model,
    GlobalMaxPooling2D()
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  sequential (Sequential)     (None, 3, 3, 2048)        23587712
#
#  global_max_pooling2d (Globa  (None, 2048)             0
#  lMaxPooling2D)
#
# ...
# Total params: 23,587,712
# Trainable params: 0
# Non-trainable params: 23,587,712
# _________________________________________________________________

# %%
import cv2
import numpy as np
from numpy.linalg import norm
from tqdm import tqdm

# %%
img=cv2.imread('C:/Users/savad/Desktop/datas/Deep learning/fashion_recommeder/Dataset/2626.jpg')
img=cv2.resize(img,(224,224))

# %%
img=np.array(img)

# %%
img.shape
# Out:
# (224, 224, 3)

# %%
expand_img=np.expand_dims(img,axis=0)
expand_img.shape
# Out:
# (1, 224, 224, 3)

# %%
pre_img=preprocess_input(expand_img)
pre_img.shape
# Out:
# (1, 224, 224, 3)

# %%
result=model.predict(pre_img).flatten()
# Out:
# 1/1 [==============================] - 0s 278ms/step

# %%
result
# Out:
# array([ 6.5963454 ,  0.10588062,  2.4345663 , ...,  0.        ,
#        13.604141  ,  4.702755  ], dtype=float32)

# %%
result.shape
# Out:
# (2048,)

# %%
normalized=result/norm(result)

# %%
def extract_feature(img_path,model):
    img=cv2.imread(img_path)
    img=cv2.resize(img,(224,224))
    img=np.array(img)
    expand_img=np.expand_dims(img,axis=0)
    pre_img=preprocess_input(expand_img)
    result=model.predict(pre_img).flatten() 
    normalized=result/norm(result) 
    return normalized

# %%
extract_feature('C:/Users/savad/Desktop/datas/Deep learning/fashion_recommeder/Dataset/2626.jpg',model)
# Out:
# 1/1 [==============================] - 0s 267ms/step
# array([0.01990709, 0.00031954, 0.00734727, ..., 0.        , 0.04105588,
#        0.01419243], dtype=float32)

# %%
import os

# %%
filename=[]
feature_list=[] 
for file in os.listdir('C:/Users/savad/Desktop/datas/Deep learning/fashion_recommeder/Dataset'):
    filename.append(os.path.join('C:/Users/savad/Desktop/datas/Deep learning/fashion_recommeder/Dataset',file))

# %%
filename[0:5]
# Out:
# ['C:/Users/savad/Desktop/datas/Deep learning/fashion_recommeder/Dataset\\10037.jpg',
#  'C:/Users/savad/Desktop/datas/Deep learning/fashion_recommeder/Dataset\\10039.jpg',
#  'C:/Users/savad/Desktop/datas/Deep learning/fashion_recommeder/Dataset\\10054.jpg',
#  'C:/Users/savad/Desktop/datas/Deep learning/fashion_recommeder/Dataset\\10096.jpg',
#  'C:/Users/savad/Desktop/datas/Deep learning/fashion_recommeder/Dataset\\10097.jpg']

# %%
for file in tqdm(filename): #tqdm for seeing process
    feature_list.append(extract_feature(file,model))
# Out:
# ...
# 1/1 [==============================] - 0s 215ms/step
# ...
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 2906/2906 [36:08<00:00,  1.34it/s]

# %%
import pickle

# %%
pickle.dump(feature_list,open('C:/Users/savad/Desktop/datas/Deep learning/fashion_recommeder/featurevector.pkl','wb'))
pickle.dump(filename,open('C:/Users/savad/Desktop/datas/Deep learning/fashion_recommeder/filename.pkl','wb'))
